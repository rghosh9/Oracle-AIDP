# %%
output_param_key= "TGT_TYPE"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "SRC_CATALOG"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "SRC_SCHEMA"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "TGT_CATALOG"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "TGT_SCHEMA"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "TGT_TAB_SCHEMA"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "TGT_VOLUME"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "FOLDER_NAME"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "OCI_BUCKET"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))

output_param_key= "TBL_LIST"
param_value = oidlUtils.parameters.getTaskValue("SET_PARAM", output_param_key, "defaultValue")
print("Param {} value is {}".format(output_param_key, param_value))
# Out:
# Param TGT_TYPE value is defaultValue
# Param SRC_CATALOG value is defaultValue
# Param SRC_SCHEMA value is defaultValue
# Param TGT_CATALOG value is defaultValue
# Param TGT_SCHEMA value is defaultValue
# Param TGT_TAB_SCHEMA value is defaultValue
# Param TGT_VOLUME value is defaultValue
# Param FOLDER_NAME value is defaultValue
# Param OCI_BUCKET value is defaultValue
# Param TBL_LIST value is defaultValue
