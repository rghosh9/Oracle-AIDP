# %% [markdown]
# #### AIDP Parameter Setting

# %%
#
# AIDP Source setup
# 
output_parameter_key = "SRC_CATALOG"
oidlUtils.parameters.setTaskValue(output_parameter_key, "psftcln")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "SRC_SCHEMA"
oidlUtils.parameters.setTaskValue(output_parameter_key, "psftcln")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "TBL_LIST" # "" all source tables otherwise comma separated e,g 'ps_account_tbl','ps_cust_tbl'
oidlUtils.parameters.setTaskValue(output_parameter_key, "")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

#
# AIDP Targets setup
# 
# AIDP Target type
output_parameter_key = "TGT_TYPE" # OS - Direct OS bucket TBL AIDP standard table VOL AIDP External Tables
oidlUtils.parameters.setTaskValue(output_parameter_key, "TAB")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "TGT_CATALOG"
oidlUtils.parameters.setTaskValue(output_parameter_key, "default")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "TGT_SCHEMA"
oidlUtils.parameters.setTaskValue(output_parameter_key, "default")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "TGT_TAB_SCHEMA"
oidlUtils.parameters.setTaskValue(output_parameter_key, "default")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "TGT_VOLUME"
oidlUtils.parameters.setTaskValue(output_parameter_key, "psftos")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "FOLDER_NAME"
oidlUtils.parameters.setTaskValue(output_parameter_key, "bronze")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")

output_parameter_key = "OCI_BUCKET"
oidlUtils.parameters.setTaskValue(output_parameter_key, "oci://AIDPTEST@orasenatdpltintegration03")
output_param_value = oidlUtils.parameters.getParameter(output_parameter_key, "defaultValue2")
print(f"key={output_parameter_key}\tvalue={output_param_value}")
# Out:
# key=TGT_TYPE	value=defaultValue2
# key=SRC_CATALOG	value=defaultValue2
# key=SRC_SCHEMA	value=defaultValue2
# key=TGT_CATALOG	value=defaultValue2
# key=TGT_SCHEMA	value=defaultValue2
# key=TGT_TAB_SCHEMA	value=defaultValue2
# key=TGT_VOLUME	value=defaultValue2
# key=FOLDER_NAME	value=defaultValue2
# key=OCI_BUCKET	value=defaultValue2
# key=TBL_LIST	value=defaultValue2
